# %%
r = []

# %%
intra = 0.05
inter = 0.05
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.12962962963
# Multiplication:  0.0185185185185
# Paths:  0.0185185185185
# Normalized:  0.0185185185185
# Pareto:  0.0185185185185
# GSG:  0.0
# GSSG:  0.0
# GSGGSG:  0.0
# Maximum paths:  0.0 , with filters:  [5, 5]
# Maximum filtered values:  0.0 , with filters:  [5, 5]
# Maximum pareto:  1.0 , with filters:  [5, 5]
# Maximum pareto on filtered:  1.0 , with filters:  [5, 5]
# Matrix filter
# Maximum paths:  0.0 , with filters:  [5, 5]
# Maximum filtered values:  0.0 , with filters:  [5, 5]
# Maximum pareto:  1.0 , with filters:  [5, 5]
# Maximum pareto on filtered:  1.0 , with filters:  [5, 5]
# Row filter

# %%
intra = 0.05
inter = 0.25
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.186092715232
# Multiplication:  0.0993377483444
# Paths:  0.0506622516556
# Normalized:  0.172185430464
# Pareto:  0.0983443708609
# GSG:  0.177483443709
# GSSG:  0.179139072848
# GSGGSG:  0.183774834437
# Maximum paths:  0.185430463576 , with filters:  [5, 35]
# Maximum filtered values:  0.193708609272 , with filters:  [5, 35]
# Maximum pareto:  0.210264900662 , with filters:  [50, 15]
# Maximum pareto on filtered:  0.196357615894 , with filters:  [10, 45]
# Matrix filter
# Maximum paths:  0.167218543046 , with filters:  [45, 50]
# Maximum filtered values:  0.189072847682 , with filters:  [85, 90]
# Maximum pareto:  0.208278145695 , with filters:  [35, 60]
# Maximum pareto on filtered:  0.185761589404 , with filters:  [10, 25]
# Row filter

# %%
intra = 0.05
inter = 0.5
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.243952160913
# Multiplication:  0.0293558032074
# Paths:  0.0154933405817
# Normalized:  0.162680076108
# Pareto:  0.0255504213101
# GSG:  0.239331340038
# GSSG:  0.232536015222
# GSGGSG:  0.240962217994
# Maximum paths:  0.250203859744 , with filters:  [15, 20]
# Maximum filtered values:  0.260940472955 , with filters:  [30, 20]
# Maximum pareto:  0.263794509378 , with filters:  [15, 20]
# Maximum pareto on filtered:  0.267599891275 , with filters:  [15, 20]
# Matrix filter
# Maximum paths:  0.233487360696 , with filters:  [35, 30]
# Maximum filtered values:  0.251427018211 , with filters:  [35, 20]
# Maximum pareto:  0.265969013319 , with filters:  [50, 40]
# Maximum pareto on filtered:  0.253057896167 , with filters:  [30, 20]
# Row filter

# %%
intra = 0.05
inter = 0.75
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.307944606414
# Multiplication:  0.0249635568513
# Paths:  0.0165816326531
# Normalized:  0.0457361516035
# Pareto:  0.0219569970845
# GSG:  0.298833819242
# GSSG:  0.184948979592
# GSGGSG:  0.255648688047
# Maximum paths:  0.292729591837 , with filters:  [5, 70]
# Maximum filtered values:  0.29764941691 , with filters:  [5, 95]
# Maximum pareto:  0.29236516035 , with filters:  [5, 55]
# Maximum pareto on filtered:  0.285167638484 , with filters:  [5, 90]
# Matrix filter
# Maximum paths:  0.253644314869 , with filters:  [85, 80]
# Maximum filtered values:  0.272685860058 , with filters:  [85, 85]
# Maximum pareto:  0.265488338192 , with filters:  [25, 10]
# Maximum pareto on filtered:  0.259201895044 , with filters:  [85, 85]
# Row filter

# %%
intra = 0.05
inter = 0.95
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.393303023743
# Multiplication:  0.0283611171249
# Paths:  0.0242476726564
# Normalized:  0.0284332828173
# Pareto:  0.0251136609656
# GSG:  0.385003969113
# GSSG:  0.0959803709317
# GSGGSG:  0.238868441943
# Maximum paths:  0.374972937865 , with filters:  [5, 70]
# Maximum filtered values:  0.374251280941 , with filters:  [5, 90]
# Maximum pareto:  0.339323085805 , with filters:  [5, 65]
# Maximum pareto on filtered:  0.362704770152 , with filters:  [5, 70]
# Matrix filter
# Maximum paths:  0.290106083568 , with filters:  [85, 85]
# Maximum filtered values:  0.31601356715 , with filters:  [85, 85]
# Maximum pareto:  0.246373673955 , with filters:  [60, 65]
# Maximum pareto on filtered:  0.301291765894 , with filters:  [85, 85]
# Row filter

# %%
intra = 0.25
inter = 0.05
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.194196428571
# Multiplication:  0.381696428571
# Paths:  0.330357142857
# Normalized:  0.310267857143
# Pareto:  0.517857142857
# GSG:  0.209821428571
# GSSG:  0.1875
# GSGGSG:  0.171875
# Maximum paths:  0.183035714286 , with filters:  [15, 75]
# Maximum filtered values:  0.227678571429 , with filters:  [75, 5]
# Maximum pareto:  0.205357142857 , with filters:  [5, 10]
# Maximum pareto on filtered:  0.216517857143 , with filters:  [75, 5]
# Matrix filter
# Maximum paths:  0.196428571429 , with filters:  [90, 75]
# Maximum filtered values:  0.238839285714 , with filters:  [90, 85]
# Maximum pareto:  0.225446428571 , with filters:  [50, 20]
# Maximum pareto on filtered:  0.229910714286 , with filters:  [90, 85]
# Row filter

# %%
intra = 0.25
inter = 0.25
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.193030220528
# Multiplication:  0.177511570923
# Paths:  0.144840729649
# Normalized:  0.188674108358
# Pareto:  0.195208276613
# GSG:  0.204192757964
# GSSG:  0.195208276613
# GSGGSG:  0.193030220528
# Maximum paths:  0.195752790634 , with filters:  [25, 50]
# Maximum filtered values:  0.210182412197 , with filters:  [35, 45]
# Maximum pareto:  0.220800435611 , with filters:  [55, 30]
# Maximum pareto on filtered:  0.20691532807 , with filters:  [25, 45]
# Matrix filter
# Maximum paths:  0.186768309284 , with filters:  [50, 35]
# Maximum filtered values:  0.208548870133 , with filters:  [95, 25]
# Maximum pareto:  0.22461203376 , with filters:  [70, 55]
# Maximum pareto on filtered:  0.205009528995 , with filters:  [45, 30]
# Row filter

# %%
intra = 0.25
inter = 0.5
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.244491472675
# Multiplication:  0.143283953691
# Paths:  0.105564546247
# Normalized:  0.146147143035
# Pareto:  0.146396116021
# GSG:  0.245487364621
# GSSG:  0.170173036226
# GSGGSG:  0.220590065978
# Maximum paths:  0.241503796838 , with filters:  [5, 60]
# Maximum filtered values:  0.243620067223 , with filters:  [5, 95]
# Maximum pareto:  0.247603635006 , with filters:  [5, 15]
# Maximum pareto on filtered:  0.236026391137 , with filters:  [5, 60]
# Matrix filter
# Maximum paths:  0.208016930163 , with filters:  [80, 80]
# Maximum filtered values:  0.22917963401 , with filters:  [85, 95]
# Maximum pareto:  0.227187850118 , with filters:  [40, 70]
# Maximum pareto on filtered:  0.217851363127 , with filters:  [85, 85]
# Row filter

# %%
intra = 0.25
inter = 0.75
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.321659850034
# Multiplication:  0.112900477164
# Paths:  0.0
# Normalized:  0.114434219496
# Pareto:  0.105743012952
# GSG:  0.321063394683
# GSSG:  0.138462849352
# GSGGSG:  0.158316291752
# Maximum paths:  0.312201772324 , with filters:  [5, 85]
# Maximum filtered values:  0.318762781186 , with filters:  [5, 95]
# Maximum pareto:  0.284338786639 , with filters:  [5, 65]
# Maximum pareto on filtered:  0.308026584867 , with filters:  [5, 85]
# Matrix filter
# Maximum paths:  0.253408316292 , with filters:  [85, 80]
# Maximum filtered values:  0.282634628494 , with filters:  [40, 100]
# Maximum pareto:  0.197767552829 , with filters:  [65, 75]
# Maximum pareto on filtered:  0.268404907975 , with filters:  [40, 100]
# Row filter

# %%
intra = 0.25
inter = 0.95
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.420663195396
# Multiplication:  0.123321457934
# Paths:  0.0
# Normalized:  0.123252946013
# Pareto:  0.107837763771
# GSG:  0.419567004659
# GSSG:  0.155659084681
# GSGGSG:  0.125171279803
# Maximum paths:  0.410591942998 , with filters:  [5, 75]
# Maximum filtered values:  0.408468073445 , with filters:  [5, 90]
# Maximum pareto:  0.370992052617 , with filters:  [5, 65]
# Maximum pareto on filtered:  0.396889558783 , with filters:  [5, 85]
# Matrix filter
# Maximum paths:  0.32015620718 , with filters:  [85, 70]
# Maximum filtered values:  0.345368594135 , with filters:  [85, 80]
# Maximum pareto:  0.210811181146 , with filters:  [60, 70]
# Maximum pareto on filtered:  0.328035078104 , with filters:  [85, 80]
# Row filter

# %%
intra = 0.5
inter = 0.05
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.183649971215
# Multiplication:  0.936672423719
# Paths:  0.900402993667
# Normalized:  0.856649395509
# Pareto:  0.929763960852
# GSG:  0.156016119747
# GSSG:  0.286125503742
# GSGGSG:  0.169257340242
# Maximum paths:  0.253886010363 , with filters:  [80, 60]
# Maximum filtered values:  0.285549798503 , with filters:  [85, 60]
# Maximum pareto:  0.227979274611 , with filters:  [75, 65]
# Maximum pareto on filtered:  0.280368451353 , with filters:  [85, 60]
# Matrix filter
# Maximum paths:  0.325273459988 , with filters:  [85, 85]
# Maximum filtered values:  0.333909038572 , with filters:  [90, 80]
# Maximum pareto:  0.269430051813 , with filters:  [65, 65]
# Maximum pareto on filtered:  0.328151986183 , with filters:  [90, 85]
# Row filter

# %%
intra = 0.5
inter = 0.25
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.206465067779
# Multiplication:  0.301772679875
# Paths:  0.154953076121
# Normalized:  0.308654848801
# Pareto:  0.295724713243
# GSG:  0.202085505735
# GSSG:  0.3228362878
# GSGGSG:  0.238790406674
# Maximum paths:  0.287382690302 , with filters:  [65, 70]
# Maximum filtered values:  0.324504692388 , with filters:  [75, 75]
# Maximum pareto:  0.283420229406 , with filters:  [65, 70]
# Maximum pareto on filtered:  0.316788321168 , with filters:  [75, 75]
# Matrix filter
# Maximum paths:  0.313868613139 , with filters:  [70, 70]
# Maximum filtered values:  0.33472367049 , with filters:  [90, 30]
# Maximum pareto:  0.302815432742 , with filters:  [55, 60]
# Maximum pareto on filtered:  0.325964546403 , with filters:  [70, 75]
# Row filter

# %%
intra = 0.5
inter = 0.5
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.267997781475
# Multiplication:  0.264780920688
# Paths:  0.0
# Normalized:  0.264891846922
# Pareto:  0.251691625069
# GSG:  0.270216306156
# GSSG:  0.267110371603
# GSGGSG:  0.269550748752
# Maximum paths:  0.263893510815 , with filters:  [20, 75]
# Maximum filtered values:  0.27443150305 , with filters:  [5, 5]
# Maximum pareto:  0.2820854132 , with filters:  [5, 15]
# Maximum pareto on filtered:  0.277093732668 , with filters:  [5, 15]
# Matrix filter
# Maximum paths:  0.259234608985 , with filters:  [25, 40]
# Maximum filtered values:  0.271214642263 , with filters:  [10, 10]
# Maximum pareto:  0.291735995563 , with filters:  [40, 60]
# Maximum pareto on filtered:  0.271547420965 , with filters:  [15, 25]
# Row filter

# %%
intra = 0.5
inter = 0.75
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.350690585807
# Multiplication:  0.25234164153
# Paths:  0.0
# Normalized:  0.25234164153
# Pareto:  0.233529131608
# GSG:  0.347674234005
# GSSG:  0.249801555803
# GSGGSG:  0.258136212097
# Maximum paths:  0.342990950945 , with filters:  [5, 70]
# Maximum filtered values:  0.342276551834 , with filters:  [5, 90]
# Maximum pareto:  0.324972217812 , with filters:  [5, 60]
# Maximum pareto on filtered:  0.336005715193 , with filters:  [5, 65]
# Matrix filter
# Maximum paths:  0.304810287347 , with filters:  [80, 65]
# Maximum filtered values:  0.325686616923 , with filters:  [85, 80]
# Maximum pareto:  0.287109064931 , with filters:  [70, 60]
# Maximum pareto on filtered:  0.31092236863 , with filters:  [80, 70]
# Row filter

# %%
intra = 0.5
inter = 0.95
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.465959785349
# Multiplication:  0.27458459947
# Paths:  0.0
# Normalized:  0.27458459947
# Pareto:  0.244585246008
# GSG:  0.465830477791
# GSSG:  0.284024051206
# GSGGSG:  0.274713907028
# Maximum paths:  0.45218853042 , with filters:  [5, 70]
# Maximum filtered values:  0.450378224607 , with filters:  [5, 90]
# Maximum pareto:  0.427490786836 , with filters:  [5, 70]
# Maximum pareto on filtered:  0.441068080429 , with filters:  [5, 70]
# Matrix filter
# Maximum paths:  0.388181289196 , with filters:  [65, 80]
# Maximum filtered values:  0.408547229586 , with filters:  [85, 75]
# Maximum pareto:  0.320682743906 , with filters:  [70, 60]
# Maximum pareto on filtered:  0.387405443848 , with filters:  [85, 75]
# Row filter

# %%
intra = 0.75
inter = 0.05
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.181655320674
# Multiplication:  0.968828376926
# Paths:  0.968828376926
# Normalized:  0.968470082408
# Pareto:  0.968828376926
# GSG:  0.178072375493
# GSSG:  0.383016839842
# GSGGSG:  0.195270512361
# Maximum paths:  0.399498387675 , with filters:  [80, 75]
# Maximum filtered values:  0.410605517736 , with filters:  [80, 70]
# Maximum pareto:  0.312791114296 , with filters:  [70, 80]
# Maximum pareto on filtered:  0.407739161591 , with filters:  [80, 75]
# Matrix filter
# Maximum paths:  0.445718380509 , with filters:  [80, 80]
# Maximum filtered values:  0.446793264063 , with filters:  [90, 75]
# Maximum pareto:  0.352561805804 , with filters:  [60, 70]
# Maximum pareto on filtered:  0.447151558581 , with filters:  [90, 80]
# Row filter

# %%
intra = 0.75
inter = 0.25
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.222753672702
# Multiplication:  0.51759480697
# Paths:  0.202425691835
# Normalized:  0.515203279809
# Pareto:  0.509053638538
# GSG:  0.200888281517
# GSSG:  0.51007857875
# GSGGSG:  0.477280491971
# Maximum paths:  0.506491288008 , with filters:  [80, 75]
# Maximum filtered values:  0.520840450974 , with filters:  [70, 70]
# Maximum pareto:  0.498462589682 , with filters:  [75, 65]
# Maximum pareto on filtered:  0.51247010591 , with filters:  [70, 10]
# Matrix filter
# Maximum paths:  0.51127434233 , with filters:  [80, 55]
# Maximum filtered values:  0.522890331397 , with filters:  [90, 75]
# Maximum pareto:  0.517423983601 , with filters:  [75, 55]
# Maximum pareto on filtered:  0.518961393919 , with filters:  [65, 55]
# Row filter

# %%
intra = 0.75
inter = 0.5
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.283753784057
# Multiplication:  0.289202825429
# Paths:  0.0
# Normalized:  0.289202825429
# Pareto:  0.275882946519
# GSG:  0.284258324924
# GSSG:  0.316649848638
# GSGGSG:  0.287386478305
# Maximum paths:  0.285671039354 , with filters:  [20, 55]
# Maximum filtered values:  0.305247225025 , with filters:  [30, 80]
# Maximum pareto:  0.298082744702 , with filters:  [20, 30]
# Maximum pareto on filtered:  0.29687184662 , with filters:  [35, 80]
# Matrix filter
# Maximum paths:  0.313521695257 , with filters:  [75, 70]
# Maximum filtered values:  0.330474268416 , with filters:  [90, 70]
# Maximum pareto:  0.337336024218 , with filters:  [70, 45]
# Maximum pareto on filtered:  0.319071644803 , with filters:  [75, 55]
# Row filter

# %%
intra = 0.75
inter = 0.75
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.383164435239
# Multiplication:  0.388786152822
# Paths:  0.0
# Normalized:  0.388786152822
# Pareto:  0.369849840965
# GSG:  0.389525852504
# GSSG:  0.386567053776
# GSGGSG:  0.389156002663
# Maximum paths:  0.38641911384 , with filters:  [5, 75]
# Maximum filtered values:  0.391892891486 , with filters:  [5, 70]
# Maximum pareto:  0.397440639101 , with filters:  [5, 10]
# Maximum pareto on filtered:  0.388934092758 , with filters:  [5, 15]
# Matrix filter
# Maximum paths:  0.374066129152 , with filters:  [25, 45]
# Maximum filtered values:  0.392336711295 , with filters:  [25, 95]
# Maximum pareto:  0.414083881944 , with filters:  [40, 75]
# Maximum pareto on filtered:  0.387750573267 , with filters:  [20, 25]
# Row filter

# %%
intra = 0.75
inter = 0.95
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.525103582744
# Multiplication:  0.455581281989
# Paths:  0.000913965391177
# Normalized:  0.455581281989
# Pareto:  0.425664148184
# GSG:  0.53077016817
# GSSG:  0.451864489398
# GSGGSG:  0.455154764806
# Maximum paths:  0.520107238606 , with filters:  [5, 75]
# Maximum filtered values:  0.523275651962 , with filters:  [5, 75]
# Maximum pareto:  0.47855227882 , with filters:  [5, 15]
# Maximum pareto on filtered:  0.50651961979 , with filters:  [5, 75]
# Matrix filter
# Maximum paths:  0.471057762613 , with filters:  [65, 80]
# Maximum filtered values:  0.496770655618 , with filters:  [65, 85]
# Maximum pareto:  0.480563002681 , with filters:  [40, 65]
# Maximum pareto on filtered:  0.4703265903 , with filters:  [65, 85]
# Row filter

# %%
intra = 0.95
inter = 0.05
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.200056116723
# Multiplication:  0.965207631874
# Paths:  0.961840628507
# Normalized:  0.966610549944
# Pareto:  0.965207631874
# GSG:  0.184904601571
# GSSG:  0.483164983165
# GSGGSG:  0.228395061728
# Maximum paths:  0.485409652076 , with filters:  [75, 75]
# Maximum filtered values:  0.491021324355 , with filters:  [70, 75]
# Maximum pareto:  0.445286195286 , with filters:  [70, 75]
# Maximum pareto on filtered:  0.490179573513 , with filters:  [70, 75]
# Matrix filter
# Maximum paths:  0.509820426487 , with filters:  [85, 75]
# Maximum filtered values:  0.510942760943 , with filters:  [85, 75]
# Maximum pareto:  0.486812570146 , with filters:  [65, 70]
# Maximum pareto on filtered:  0.511503928171 , with filters:  [50, 80]
# Row filter

# %%
intra = 0.95
inter = 0.25
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.221524663677
# Multiplication:  0.595216741405
# Paths:  0.206576980568
# Normalized:  0.594618834081
# Pareto:  0.595067264574
# GSG:  0.216292974589
# GSSG:  0.564275037369
# GSGGSG:  0.589387144993
# Maximum paths:  0.58355754858 , with filters:  [80, 60]
# Maximum filtered values:  0.591928251121 , with filters:  [80, 35]
# Maximum pareto:  0.594170403587 , with filters:  [15, 10]
# Maximum pareto on filtered:  0.588490284006 , with filters:  [55, 10]
# Matrix filter
# Maximum paths:  0.588340807175 , with filters:  [80, 50]
# Maximum filtered values:  0.597608370703 , with filters:  [80, 50]
# Maximum pareto:  0.598206278027 , with filters:  [75, 50]
# Maximum pareto on filtered:  0.594020926756 , with filters:  [70, 50]
# Row filter

# %%
intra = 0.95
inter = 0.5
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.303573112096
# Multiplication:  0.453568398228
# Paths:  0.0
# Normalized:  0.453568398228
# Pareto:  0.441783727727
# GSG:  0.296125200339
# GSSG:  0.470066936928
# GSGGSG:  0.45243706986
# Maximum paths:  0.450268690487 , with filters:  [80, 60]
# Maximum filtered values:  0.469689827472 , with filters:  [75, 10]
# Maximum pareto:  0.454134062412 , with filters:  [75, 50]
# Maximum pareto on filtered:  0.457999434336 , with filters:  [75, 70]
# Matrix filter
# Maximum paths:  0.46186480626 , with filters:  [85, 65]
# Maximum filtered values:  0.474686527765 , with filters:  [85, 65]
# Maximum pareto:  0.482228716885 , with filters:  [75, 50]
# Maximum pareto on filtered:  0.46940699538 , with filters:  [65, 45]
# Row filter

# %%
intra = 0.95
inter = 0.75
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.414169129028
# Multiplication:  0.417053609118
# Paths:  0.0
# Normalized:  0.417053609118
# Pareto:  0.398480371465
# GSG:  0.40678204587
# GSSG:  0.464049528634
# GSGGSG:  0.417968200366
# Maximum paths:  0.420430561418 , with filters:  [15, 15]
# Maximum filtered values:  0.457295624033 , with filters:  [25, 20]
# Maximum pareto:  0.439918390319 , with filters:  [15, 15]
# Maximum pareto on filtered:  0.445335584635 , with filters:  [25, 20]
# Matrix filter
# Maximum paths:  0.447657239341 , with filters:  [45, 35]
# Maximum filtered values:  0.469748135641 , with filters:  [30, 25]
# Maximum pareto:  0.476572393415 , with filters:  [35, 35]
# Maximum pareto on filtered:  0.46060222316 , with filters:  [10, 30]
# Row filter

# %%
intra = 0.95
inter = 0.95
# %run test2.ipynb
r.append(result)
# Out:
# Baseline:  0.58012277112
# Multiplication:  0.578661210172
# Paths:  0.0
# Normalized:  0.578661210172
# Pareto:  0.549020754165
# GSG:  0.57871967261
# GSSG:  0.581935106694
# GSGGSG:  0.578485822859
# Maximum paths:  0.576030400468 , with filters:  [15, 60]
# Maximum filtered values:  0.581525869629 , with filters:  [5, 60]
# Maximum pareto:  0.588892136802 , with filters:  [5, 10]
# Maximum pareto on filtered:  0.573925752704 , with filters:  [5, 10]
# Matrix filter
# Maximum paths:  0.562759427068 , with filters:  [50, 45]
# Maximum filtered values:  0.582812043262 , with filters:  [20, 95]
# Maximum pareto:  0.598596901491 , with filters:  [25, 60]
# Maximum pareto on filtered:  0.564747149956 , with filters:  [20, 35]
# Row filter

# %%
import pickle
pickle.dump(r, open("synth.pickle", "wb"))

# %%
import Orange
from scipy.stats import rankdata
names = ["Baseline","Multiplication","GSG","GSSG",
         "GSGGSG","Paths","Normalized","Pareto","MF_FV","MF_PF",
         "MF_Par","MF_Pat","RF_Pat","RF_FV","RF_Par","RF_PF"]
ranks = np.zeros((len(names), len(r)))
for i, res in enumerate(r):
    pred = []
    for name in names:
        pred.append(res[name])
    ranks[:,i] = 17-rankdata(pred, method="min")
avranks = np.mean(ranks, axis=1)

cd = Orange.evaluation.compute_CD(avranks, len(r), alpha='0.1')
Orange.evaluation.graph_ranks(avranks, names, cd=cd, width=6, textspace=1.5)
plt.show()

# %%
cd = Orange.evaluation.compute_CD(avranks, len(r), alpha='0.05')
Orange.evaluation.graph_ranks(avranks, names, cd=cd, width=6, textspace=1.5)
plt.show()
